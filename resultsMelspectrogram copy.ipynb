# %%
from modelGym import load_data,run_model
from src.models import model_1,model_2,model_3,model_4, model_5, model_6, dnn, dnn_1, dnn_2, dnn_3, dnn_4, dnn_5, dnn_6,dnn_7,dnn_8
# Out:
# 2023-06-21 19:41:57.037952: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 19:41:58.490933: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 19:41:58.493643: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 19:42:02.654270: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Data Split (melspectrogram power to db = true)

# %%
train_X, train_Y, cv_X, cv_Y, test_X, test_Y = load_data("melspectrogram")

print(len(train_X), len(cv_X), len(test_X))
# Out:
# 1800 600 600

# %% [markdown]
# # Model 1

# %%
print("Running model 1")
loss, accuracy = run_model(model_1(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 1
# Epoch 1/50
# /home/mariana/Desktop/lei-taa-2/venv/lib/python3.9/site-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 10/57 [====>.........................] - ETA: 0s - loss: 2.5528 - accuracy: 0.3125
# 2023-06-21 19:42:10.348877: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 14155776 exceeds 10% of free system memory.
# 2023-06-21 19:42:10.349051: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 14155776 exceeds 10% of free system memory.
# 2023-06-21 19:42:10.376723: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 14155776 exceeds 10% of free system memory.
# ...

# %% [markdown]
# # Model 2

# %%
print("Running model 2")
loss, accuracy = run_model(model_2(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 2
# Epoch 1/50
# /home/mariana/Desktop/lei-taa-2/venv/lib/python3.9/site-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 57/57 [==============================] - 3s 29ms/step - loss: 1.7036 - accuracy: 0.4678 - val_loss: 4.4740 - val_accuracy: 0.1000
# Epoch 2/50
# 57/57 [==============================] - 2s 28ms/step - loss: 0.7341 - accuracy: 0.7494 - val_loss: 2.2741 - val_accuracy: 0.2300
# Epoch 3/50
# 57/57 [==============================] - 1s 26ms/step - loss: 0.3752 - accuracy: 0.8728 - val_loss: 0.9978 - val_accuracy: 0.6717
# Epoch 4/50
# 57/57 [==============================] - 1s 25ms/step - loss: 0.2659 - accuracy: 0.9161 - val_loss: 0.6154 - val_accuracy: 0.8017
# Epoch 5/50
# ...

# %% [markdown]
# # Model 3

# %%
print("Running model 3")
loss, accuracy = run_model(model_3(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 3
# Epoch 1/50
# 57/57 [==============================] - 3s 49ms/step - loss: 3.2175 - accuracy: 0.3067 - val_loss: 1.6853 - val_accuracy: 0.3883
# Epoch 2/50
# 57/57 [==============================] - 2s 41ms/step - loss: 0.9687 - accuracy: 0.6467 - val_loss: 1.0854 - val_accuracy: 0.5700
# Epoch 3/50
# 57/57 [==============================] - 3s 44ms/step - loss: 0.6308 - accuracy: 0.7889 - val_loss: 0.2267 - val_accuracy: 0.9183
# Epoch 4/50
# 57/57 [==============================] - 3s 44ms/step - loss: 0.3621 - accuracy: 0.8733 - val_loss: 0.3230 - val_accuracy: 0.8783
# Epoch 5/50
# 57/57 [==============================] - 3s 46ms/step - loss: 0.3025 - accuracy: 0.9039 - val_loss: 0.2439 - val_accuracy: 0.9000
# Epoch 6/50
# 57/57 [==============================] - 2s 44ms/step - loss: 0.2452 - accuracy: 0.9211 - val_loss: 0.1512 - val_accuracy: 0.9650
# Epoch 7/50
# ...

# %% [markdown]
# # Model 4

# %%
print("Running model 4")
loss, accuracy = run_model(model_4(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 4
# Epoch 1/50
# 57/57 [==============================] - 2s 35ms/step - loss: 3.4109 - accuracy: 0.2328 - val_loss: 1.3898 - val_accuracy: 0.6000
# Epoch 2/50
# 57/57 [==============================] - 2s 36ms/step - loss: 1.0462 - accuracy: 0.6294 - val_loss: 0.4390 - val_accuracy: 0.9033
# Epoch 3/50
# 57/57 [==============================] - 2s 41ms/step - loss: 0.5993 - accuracy: 0.7956 - val_loss: 0.2752 - val_accuracy: 0.9300
# Epoch 4/50
# 57/57 [==============================] - 3s 50ms/step - loss: 0.4756 - accuracy: 0.8372 - val_loss: 0.2305 - val_accuracy: 0.9300
# Epoch 5/50
# 57/57 [==============================] - 3s 53ms/step - loss: 0.4222 - accuracy: 0.8528 - val_loss: 0.2299 - val_accuracy: 0.9400
# Epoch 6/50
# 57/57 [==============================] - 3s 51ms/step - loss: 0.3777 - accuracy: 0.8650 - val_loss: 0.1567 - val_accuracy: 0.9567
# Epoch 7/50
# ...

# %% [markdown]
# # Model 5

# %%
print("Running model 5")
loss, accuracy = run_model(model_5(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 5
# Epoch 1/50
# 57/57 [==============================] - 2s 27ms/step - loss: 2.9875 - accuracy: 0.2294 - val_loss: 1.4302 - val_accuracy: 0.5117
# Epoch 2/50
# 57/57 [==============================] - 1s 25ms/step - loss: 1.2061 - accuracy: 0.5728 - val_loss: 0.6288 - val_accuracy: 0.8633
# Epoch 3/50
# 57/57 [==============================] - 1s 25ms/step - loss: 0.7085 - accuracy: 0.7506 - val_loss: 0.3107 - val_accuracy: 0.9117
# Epoch 4/50
# 57/57 [==============================] - 1s 25ms/step - loss: 0.6162 - accuracy: 0.7772 - val_loss: 0.2704 - val_accuracy: 0.9183
# Epoch 5/50
# 57/57 [==============================] - 1s 25ms/step - loss: 0.4786 - accuracy: 0.8333 - val_loss: 0.2388 - val_accuracy: 0.9333
# Epoch 6/50
# 57/57 [==============================] - 1s 26ms/step - loss: 0.4132 - accuracy: 0.8561 - val_loss: 0.1876 - val_accuracy: 0.9500
# Epoch 7/50
# ...

# %% [markdown]
# # Model 6

# %%
print("Running model 6")
loss, accuracy = run_model(model_6(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running model 6
# Epoch 1/50
# 57/57 [==============================] - 7s 86ms/step - loss: 6.4331 - accuracy: 0.1311 - val_loss: 2.3008 - val_accuracy: 0.0983
# Epoch 2/50
# 57/57 [==============================] - 2s 40ms/step - loss: 2.2193 - accuracy: 0.1772 - val_loss: 2.0472 - val_accuracy: 0.2533
# Epoch 3/50
# 57/57 [==============================] - 2s 41ms/step - loss: 1.9894 - accuracy: 0.2794 - val_loss: 1.5920 - val_accuracy: 0.4400
# Epoch 4/50
# 57/57 [==============================] - 2s 34ms/step - loss: 1.5286 - accuracy: 0.4444 - val_loss: 1.0861 - val_accuracy: 0.6283
# Epoch 5/50
# 57/57 [==============================] - 2s 28ms/step - loss: 0.8949 - accuracy: 0.6956 - val_loss: 0.4276 - val_accuracy: 0.8550
# Epoch 6/50
# 57/57 [==============================] - 2s 34ms/step - loss: 0.3856 - accuracy: 0.8789 - val_loss: 0.2955 - val_accuracy: 0.9067
# Epoch 7/50
# ...

# %% [markdown]
# # DNN

# %%
print("Running DNN")
loss, accuracy = run_model(dnn(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running DNN
# Epoch 1/50
# 57/57 [==============================] - 1s 8ms/step - loss: 48.5655 - accuracy: 0.1494 - val_loss: 5.5912 - val_accuracy: 0.2433
# Epoch 2/50
# 57/57 [==============================] - 0s 5ms/step - loss: 2.9616 - accuracy: 0.1850 - val_loss: 2.2421 - val_accuracy: 0.0900
# Epoch 3/50
# 57/57 [==============================] - 0s 4ms/step - loss: 2.2337 - accuracy: 0.1694 - val_loss: 2.1839 - val_accuracy: 0.1783
# Epoch 4/50
# 57/57 [==============================] - 0s 4ms/step - loss: 2.2219 - accuracy: 0.1500 - val_loss: 2.1995 - val_accuracy: 0.1500
# Epoch 5/50
# 57/57 [==============================] - 0s 4ms/step - loss: 2.2135 - accuracy: 0.1611 - val_loss: 2.1869 - val_accuracy: 0.1683
# Epoch 6/50
# 57/57 [==============================] - 0s 4ms/step - loss: 2.1995 - accuracy: 0.1517 - val_loss: 2.1843 - val_accuracy: 0.1633
# Epoch 7/50
# ...

# %%
print("Running dnn1")
loss, accuracy = run_model(dnn_1(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn1
# Epoch 1/50
# 57/57 [==============================] - 1s 6ms/step - loss: 55.9751 - accuracy: 0.1883 - val_loss: 15.8297 - val_accuracy: 0.3083
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 10.2917 - accuracy: 0.4061 - val_loss: 12.4291 - val_accuracy: 0.3683
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 7.0484 - accuracy: 0.5394 - val_loss: 4.9949 - val_accuracy: 0.5617
# Epoch 4/50
# 57/57 [==============================] - 0s 3ms/step - loss: 4.8184 - accuracy: 0.6328 - val_loss: 6.0231 - val_accuracy: 0.5917
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 5.4727 - accuracy: 0.6394 - val_loss: 5.6062 - val_accuracy: 0.6233
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 5.8849 - accuracy: 0.6322 - val_loss: 3.5888 - val_accuracy: 0.6983
# Epoch 7/50
# ...

# %%
print("Running dnn2")
loss, accuracy = run_model(dnn_2(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn2
# Epoch 1/50
# 57/57 [==============================] - 1s 6ms/step - loss: 49.7477 - accuracy: 0.1983 - val_loss: 13.0657 - val_accuracy: 0.3200
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 12.6941 - accuracy: 0.4011 - val_loss: 14.3331 - val_accuracy: 0.4483
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 6.7208 - accuracy: 0.5556 - val_loss: 10.8812 - val_accuracy: 0.4567
# Epoch 4/50
# 57/57 [==============================] - 0s 4ms/step - loss: 6.0945 - accuracy: 0.6067 - val_loss: 5.6414 - val_accuracy: 0.6533
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 7.0140 - accuracy: 0.5950 - val_loss: 6.4255 - val_accuracy: 0.5950
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 2.8515 - accuracy: 0.7533 - val_loss: 12.6315 - val_accuracy: 0.3733
# Epoch 7/50
# ...

# %%
print("Running dnn3")
loss, accuracy = run_model(dnn_3(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn3
# Epoch 1/50
# 57/57 [==============================] - 1s 9ms/step - loss: 114.0580 - accuracy: 0.2072 - val_loss: 28.9724 - val_accuracy: 0.3283
# Epoch 2/50
# 57/57 [==============================] - 0s 5ms/step - loss: 19.5851 - accuracy: 0.4322 - val_loss: 10.4962 - val_accuracy: 0.5883
# Epoch 3/50
# 57/57 [==============================] - 0s 4ms/step - loss: 15.0779 - accuracy: 0.5350 - val_loss: 3.6434 - val_accuracy: 0.7317
# Epoch 4/50
# 57/57 [==============================] - 0s 5ms/step - loss: 10.8800 - accuracy: 0.6061 - val_loss: 9.6106 - val_accuracy: 0.5367
# Epoch 5/50
# 57/57 [==============================] - 0s 5ms/step - loss: 9.5382 - accuracy: 0.6511 - val_loss: 9.8112 - val_accuracy: 0.7217
# Epoch 6/50
# 57/57 [==============================] - 0s 4ms/step - loss: 11.7533 - accuracy: 0.6472 - val_loss: 7.5963 - val_accuracy: 0.7050
# Epoch 7/50
# ...

# %%
print("Running dnn4")
loss, accuracy = run_model(dnn_4(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn4
# Epoch 1/50
# 57/57 [==============================] - 1s 7ms/step - loss: 116.7179 - accuracy: 0.1550 - val_loss: 44.4513 - val_accuracy: 0.3133
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 16.9858 - accuracy: 0.4639 - val_loss: 14.5749 - val_accuracy: 0.4017
# Epoch 3/50
# 57/57 [==============================] - 0s 4ms/step - loss: 11.3270 - accuracy: 0.5228 - val_loss: 18.1682 - val_accuracy: 0.4317
# Epoch 4/50
# 57/57 [==============================] - 0s 3ms/step - loss: 10.8942 - accuracy: 0.5961 - val_loss: 3.6647 - val_accuracy: 0.7133
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 2.5536 - accuracy: 0.7822 - val_loss: 4.5454 - val_accuracy: 0.6433
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 5.3021 - accuracy: 0.6917 - val_loss: 5.5996 - val_accuracy: 0.6383
# Epoch 7/50
# ...

# %%
print("Running dnn5")
loss, accuracy = run_model(dnn_5(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn5
# Epoch 1/50
# 57/57 [==============================] - 1s 5ms/step - loss: 9544.7031 - accuracy: 0.1633 - val_loss: 1836.4805 - val_accuracy: 0.2700
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 694.7979 - accuracy: 0.5011 - val_loss: 732.1235 - val_accuracy: 0.4683
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 504.2752 - accuracy: 0.5644 - val_loss: 216.9151 - val_accuracy: 0.7017
# Epoch 4/50
# 57/57 [==============================] - 0s 3ms/step - loss: 499.3490 - accuracy: 0.5883 - val_loss: 541.0387 - val_accuracy: 0.4617
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 440.7223 - accuracy: 0.6500 - val_loss: 355.3997 - val_accuracy: 0.6067
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 212.3764 - accuracy: 0.7656 - val_loss: 194.2849 - val_accuracy: 0.8033
# Epoch 7/50
# ...

# %%
print("Running dnn6")
loss, accuracy = run_model(dnn_6(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn6
# Epoch 1/50
# 57/57 [==============================] - 1s 5ms/step - loss: 8821.9844 - accuracy: 0.1611 - val_loss: 1725.5583 - val_accuracy: 0.2583
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 1269.5934 - accuracy: 0.4211 - val_loss: 478.4973 - val_accuracy: 0.4867
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 571.1381 - accuracy: 0.5517 - val_loss: 230.3839 - val_accuracy: 0.6767
# Epoch 4/50
# 57/57 [==============================] - 0s 4ms/step - loss: 438.9597 - accuracy: 0.5811 - val_loss: 1016.3550 - val_accuracy: 0.4833
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 597.4635 - accuracy: 0.6078 - val_loss: 255.6699 - val_accuracy: 0.7050
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 189.0241 - accuracy: 0.7756 - val_loss: 113.8706 - val_accuracy: 0.8250
# Epoch 7/50
# ...

# %%
print("Running dnn7")
loss, accuracy = run_model(dnn_7(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn7
# Epoch 1/50
# 57/57 [==============================] - 1s 6ms/step - loss: 51866.3164 - accuracy: 0.1183 - val_loss: 14147.7764 - val_accuracy: 0.1883
# Epoch 2/50
# 57/57 [==============================] - 0s 3ms/step - loss: 5182.4839 - accuracy: 0.3172 - val_loss: 3929.3455 - val_accuracy: 0.2517
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 2180.3918 - accuracy: 0.4156 - val_loss: 1042.3984 - val_accuracy: 0.5350
# Epoch 4/50
# 57/57 [==============================] - 0s 3ms/step - loss: 1439.1597 - accuracy: 0.5206 - val_loss: 1526.6617 - val_accuracy: 0.5600
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 22836.2305 - accuracy: 0.2861 - val_loss: 46475.4883 - val_accuracy: 0.1250
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 13019.2725 - accuracy: 0.3617 - val_loss: 2584.4875 - val_accuracy: 0.5667
# Epoch 7/50
# ...

# %%
print("Running dnn8")
loss, accuracy = run_model(dnn_8(train_X), train_X, train_Y, cv_X, cv_Y, test_X, test_Y, plot=True)
print(f"loss: {loss}, accuracy: {accuracy}")
# Out:
# Running dnn8
# Epoch 1/50
# 57/57 [==============================] - 1s 5ms/step - loss: 329941.2500 - accuracy: 0.0900 - val_loss: 52639.6602 - val_accuracy: 0.0850
# Epoch 2/50
# 57/57 [==============================] - 0s 4ms/step - loss: 408722.5938 - accuracy: 0.1050 - val_loss: 4560819.0000 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 57/57 [==============================] - 0s 3ms/step - loss: 861326.0000 - accuracy: 0.1078 - val_loss: 211841.7500 - val_accuracy: 0.1050
# Epoch 4/50
# 57/57 [==============================] - 0s 4ms/step - loss: 104224.8984 - accuracy: 0.2500 - val_loss: 26468.0879 - val_accuracy: 0.4367
# Epoch 5/50
# 57/57 [==============================] - 0s 3ms/step - loss: 10784.2998 - accuracy: 0.5161 - val_loss: 6149.0400 - val_accuracy: 0.5483
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 3435.5500 - accuracy: 0.6961 - val_loss: 1567.5701 - val_accuracy: 0.8167
# Epoch 7/50
# ...
